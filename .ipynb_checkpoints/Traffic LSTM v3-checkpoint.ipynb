# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, BatchNormalization
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
df_data = pd.read_csv('traffic.csv')
print(df_data.shape)
# Out:
# (8760, 4)

# %%
df_data.head(10)
# Out:
#          Date  Weekday  Time  Traffic
# 0  2014-01-01        4     0      581
# 1  2014-01-01        4     1      532
# 2  2014-01-01        4     2      465
# 3  2014-01-01        4     3      432
# 4  2014-01-01        4     4      297
# 5  2014-01-01        4     5      283
# 6  2014-01-01        4     6      264
# 7  2014-01-01        4     7      350
# 8  2014-01-01        4     8      458
# 9  2014-01-01        4     9      706

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 4 columns):
# Date       8760 non-null object
# Weekday    8760 non-null int64
# Time       8760 non-null int64
# Traffic    8760 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 273.9+ KB

# %%
#   df_data['Time'] = pd.to_datetime(df_data['Time'])

# %%
''' 
hour, minute, second = [], [], []
for i in range(np.size(df_data, 0)):
    hour.append(df_data['Time'][i].hour)
    minute.append(df_data['Time'][i].minute)
    second.append(df_data['Time'][i].second)
    '''
# Out:
# " \nhour, minute, second = [], [], []\nfor i in range(np.size(df_data, 0)):\n    hour.append(df_data['Time'][i].hour)\n    minute.append(df_data['Time'][i].minute)\n    second.append(df_data['Time'][i].second)\n    "

# %%
'''
hour = np.array(hour).reshape(-1, 1)
minute = np.array(minute).reshape(-1, 1)
second = np.array(second).reshape(-1, 1)

print(hour.shape, minute.shape, second.shape)
'''
# Out:
# '\nhour = np.array(hour).reshape(-1, 1)\nminute = np.array(minute).reshape(-1, 1)\nsecond = np.array(second).reshape(-1, 1)\n\nprint(hour.shape, minute.shape, second.shape)\n'

# %%
traffic = df_data['Traffic'].values.reshape(-1, 1)
print(traffic.shape)
# Out:
# (8760, 1)

# %%
time = df_data['Time'].values.reshape(-1, 1)
print(time.shape)
# Out:
# (8760, 1)

# %%
weekday = df_data['Weekday'].values.reshape(-1, 1)
print(weekday.shape)
# Out:
# (8760, 1)

# %%
data = np.concatenate((weekday, time, traffic), axis=1)
print(data.shape)
# Out:
# (8760, 3)

# %%
data[:10]
# Out:
# array([[  4,   0, 581],
#        [  4,   1, 532],
#        [  4,   2, 465],
#        [  4,   3, 432],
#        [  4,   4, 297],
#        [  4,   5, 283],
#        [  4,   6, 264],
#        [  4,   7, 350],
#        [  4,   8, 458],
#        [  4,   9, 706]], dtype=int64)

# %%
train_data = data[:7000]
train_traffic = traffic[:7000]
print(train_data.shape, train_traffic.shape)
# Out:
# (7000, 3) (7000, 1)

# %%
test_data = data[7001:]
test_traffic = traffic[7001:]
print(test_data.shape, test_traffic.shape)
# Out:
# (1759, 3) (1759, 1)

# %%
lag=24 # 몇개 데이터 후를 예측 ?

# %%
arr = []
for i in range(24):
    arr.append(train_data[i:i-lag,:])

arr = np.array(arr, dtype=np.float32)
print(arr.shape)
# Out:
# (24, 6976, 3)

# %%
#arr[:15,:10,:4]

# %%
x_train_val = np.concatenate((arr[0], arr[1], arr[2], arr[3], arr[4]), axis=1).reshape(-1, 5, 3)
#, arr[5], arr[6], arr[7], arr[8], arr[9], arr[10], arr[11], arr[12], arr[13], arr[14], arr[15], arr[16], arr[17], arr[18], arr[19], arr[20], arr[21], arr[22], arr[23]
train_mean, train_std = np.mean(x_train_val, axis=0), np.std(x_train_val, axis=0)
train_mean, train_std = np.mean(train_mean, axis=0), np.mean(train_std, axis=0)

# %%
y_train_val = train_traffic[lag:, :].reshape(-1, 1)

# %%
print(x_train_val.shape, y_train_val.shape)
# Out:
# (6976, 5, 3) (6976, 1)

# %%
arr = []
for i in range(24):
    arr.append(test_data[i:i-lag,:])
    
arr = np.array(arr, dtype=np.float32)
print(arr.shape)
# Out:
# (24, 1735, 3)

# %%
x_test = np.concatenate((arr[0], arr[1], arr[2], arr[3], arr[4]), axis=1).reshape(-1, 5, 3)
y_test = test_traffic[lag:, :].reshape(-1, 1)
print(x_test.shape, y_test.shape)
# Out:
# (1735, 5, 3) (1735, 1)

# %%
# split into training and validation datasets
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.2)
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (5580, 5, 3) (5580, 1) (1396, 5, 3) (1396, 1)

# %%
h_units = 32
activation_ = 'relu'

def rnn_model():
    model = Sequential()
    
    model.add(LSTM(units=h_units, return_sequences=True, input_shape=(5, 3))) #마지막 LSTM은 FALSE로 끝나야함
    model.add(LSTM(units=h_units, return_sequences=False)) #마지막 LSTM은 FALSE로 끝나야함
    model.add(Dense(64))
    model.add(Dense(1))
    
    return model

# %%
# create a model 
model = rnn_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 5, 32)             4608
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 15,105
# Trainable params: 15,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# training
tensorBoard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)

hist = model.fit(x_train, y_train, epochs=100, batch_size=512, verbose=True, validation_data=(x_val, y_val), shuffle=True, callbacks=[tensorBoard])
# Out:
# Train on 5580 samples, validate on 1396 samples
# Epoch 1/100
# 5580/5580 [==============================] - 1s 212us/step - loss: 2294478.0536 - val_loss: 2306127.3352
# Epoch 2/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 2288416.9013 - val_loss: 2297850.5845
# Epoch 3/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 2277311.1057 - val_loss: 2282680.3832
# Epoch 4/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 2258469.0536 - val_loss: 2259334.9835
# Epoch 5/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 2232216.2104 - val_loss: 2229974.7801
# Epoch 6/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 2203167.4984 - val_loss: 2201407.2851
# Epoch 7/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 2174346.9263 - val_loss: 2171469.7586
# Epoch 8/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 2143551.6803 - val_loss: 2139274.3431
# Epoch 9/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 2110415.7597 - val_loss: 2104157.0645
# Epoch 10/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 2074648.4297 - val_loss: 2067168.9051
# Epoch 11/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 2037081.0537 - val_loss: 2028280.3066
# Epoch 12/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 1997496.8748 - val_loss: 1987378.3818
# Epoch 13/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1955959.8108 - val_loss: 1944601.3223
# Epoch 14/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 1912710.4849 - val_loss: 1899991.7450
# Epoch 15/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1867685.1484 - val_loss: 1853889.9703
# Epoch 16/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1821278.6850 - val_loss: 1806396.5774
# Epoch 17/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 1773577.6358 - val_loss: 1757718.1913
# Epoch 18/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1724739.3402 - val_loss: 1708088.7575
# Epoch 19/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 1675052.5459 - val_loss: 1657688.3929
# Epoch 20/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1624817.6473 - val_loss: 1606644.1264
# Epoch 21/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1574034.2841 - val_loss: 1555309.2120
# Epoch 22/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1522956.9332 - val_loss: 1503946.9495
# Epoch 23/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1472096.9977 - val_loss: 1452595.1723
# Epoch 24/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1421321.9770 - val_loss: 1401615.6841
# Epoch 25/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1371031.5787 - val_loss: 1351159.8266
# Epoch 26/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1321597.8927 - val_loss: 1301269.8499
# Epoch 27/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1272548.1018 - val_loss: 1252633.3489
# Epoch 28/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1224971.2260 - val_loss: 1204956.1823
# Epoch 29/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1178280.3107 - val_loss: 1158774.3496
# Epoch 30/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 1133121.0836 - val_loss: 1114038.7382
# Epoch 31/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 1089552.9456 - val_loss: 1070824.4939
# Epoch 32/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1047529.1116 - val_loss: 1029396.6975
# Epoch 33/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 1007499.1009 - val_loss: 989668.9930
# Epoch 34/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 969024.5143 - val_loss: 952099.7794
# Epoch 35/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 932831.6518 - val_loss: 916408.8863
# Epoch 36/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 898742.6417 - val_loss: 882640.5428
# Epoch 37/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 866089.3604 - val_loss: 851445.5743
# Epoch 38/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 836311.6275 - val_loss: 821963.2973
# Epoch 39/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 808327.0731 - val_loss: 794571.0562
# Epoch 40/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 782257.3994 - val_loss: 769447.8632
# Epoch 41/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 758489.8531 - val_loss: 746268.3311
# Epoch 42/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 736461.0739 - val_loss: 724546.9912
# Epoch 43/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 712858.5062 - val_loss: 689902.7199
# Epoch 44/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 638996.6924 - val_loss: 603101.7624
# Epoch 45/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 587096.3219 - val_loss: 570847.6948
# Epoch 46/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 629825.7007 - val_loss: 623303.3053
# Epoch 47/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 595686.7240 - val_loss: 541965.6543
# Epoch 48/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 513397.0121 - val_loss: 490877.5043
# Epoch 49/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 467319.6873 - val_loss: 446620.3971
# Epoch 50/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 428837.5121 - val_loss: 414802.8502
# Epoch 51/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 395894.8550 - val_loss: 380424.4674
# Epoch 52/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 362990.7494 - val_loss: 349688.4125
# Epoch 53/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 339446.3903 - val_loss: 323275.6434
# Epoch 54/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 310791.2083 - val_loss: 302546.5339
# Epoch 55/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 287430.0060 - val_loss: 278297.6350
# Epoch 56/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 265568.5768 - val_loss: 257529.8755
# Epoch 57/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 243501.1281 - val_loss: 239279.8806
# Epoch 58/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 239489.9299 - val_loss: 279871.7058
# Epoch 59/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 245840.2169 - val_loss: 244106.2338
# Epoch 60/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 266967.9211 - val_loss: 304195.1718
# Epoch 61/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 251867.7175 - val_loss: 211221.5890
# Epoch 62/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 213584.1881 - val_loss: 224958.0810
# Epoch 63/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 198207.4598 - val_loss: 184843.3660
# Epoch 64/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 175900.0080 - val_loss: 168978.3052
# Epoch 65/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 159946.0914 - val_loss: 153178.0573
# Epoch 66/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 142417.0233 - val_loss: 146562.3577
# Epoch 67/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 132819.7095 - val_loss: 135510.6981
# Epoch 68/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 125899.7609 - val_loss: 126807.6912
# Epoch 69/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 115975.5787 - val_loss: 117476.2898
# Epoch 70/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 107028.1212 - val_loss: 116611.8228
# Epoch 71/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 103432.8037 - val_loss: 107015.7527
# Epoch 72/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 95493.8483 - val_loss: 98527.2412
# Epoch 73/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 89485.9274 - val_loss: 104133.3589
# Epoch 74/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 129591.1748 - val_loss: 163639.7235
# Epoch 75/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 146987.5114 - val_loss: 150656.6389
# Epoch 76/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 132720.3263 - val_loss: 129955.8324
# Epoch 77/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 119037.2160 - val_loss: 112251.2553
# Epoch 78/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 94578.2889 - val_loss: 91227.8251
# Epoch 79/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 81717.1663 - val_loss: 90851.8835
# Epoch 80/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 78104.3050 - val_loss: 79408.9893
# Epoch 81/100
# 5580/5580 [==============================] - 0s 43us/step - loss: 72748.7717 - val_loss: 79067.8560
# Epoch 82/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 68942.6306 - val_loss: 72681.9789
# Epoch 83/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 65229.1818 - val_loss: 69048.0964
# Epoch 84/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 62257.9721 - val_loss: 66678.3292
# Epoch 85/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 61453.8091 - val_loss: 66402.9962
# Epoch 86/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 58844.3827 - val_loss: 62360.3955
# Epoch 87/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 56994.9194 - val_loss: 60817.8082
# Epoch 88/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 56180.5918 - val_loss: 60109.5755
# Epoch 89/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 55445.7508 - val_loss: 63806.4918
# Epoch 90/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 54456.9130 - val_loss: 61223.3003
# Epoch 91/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 51751.7558 - val_loss: 55991.2354
# Epoch 92/100
# 5580/5580 [==============================] - 0s 40us/step - loss: 51721.0961 - val_loss: 56037.4726
# Epoch 93/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 50167.4321 - val_loss: 54607.0763
# Epoch 94/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 48814.0920 - val_loss: 54137.2523
# Epoch 95/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 49648.0037 - val_loss: 54027.9500
# Epoch 96/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 46721.1762 - val_loss: 52118.8305
# Epoch 97/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 47184.7920 - val_loss: 49978.4131
# Epoch 98/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 55921.0034 - val_loss: 64036.0307
# Epoch 99/100
# 5580/5580 [==============================] - 0s 42us/step - loss: 60374.9228 - val_loss: 51293.4021
# Epoch 100/100
# 5580/5580 [==============================] - 0s 41us/step - loss: 52791.3990 - val_loss: 51224.0957

# %%
y_pred = model.predict(x_test, batch_size=512, verbose=True) 
print(y_pred.shape)
print(model.evaluate(x_test, y_test,batch_size=512))
# Out:
# 1735/1735 [==============================] - 0s 176us/step
# (1735, 1)
# 1735/1735 [==============================] - 0s 18us/step
# 50809.927411293225

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

loss_ax.plot(hist.history['loss'], 'b', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='test loss')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')

loss_ax.legend(loc='upper right')

plt.show()

# %%
# visualization for prediction result
# set figure size
plt.figure(figsize=(19,8))

# set font
font = {'family': 'Arial', 'weight': 'normal', 'size': 16}
plt.rc('font', **font)

# plot data 
plt.plot(y_test[:,0], 'r', label='y_true')
plt.plot(y_pred[:,0], 'b', label='y_pred')

# set legend position
plt.legend(shadow=True, loc='upper right')

# set x-axis & y-axis titles
#plt.title('prediction result')
plt.xlabel('Time Index')
plt.ylabel('Brightness')

# set axis-limits
plt.xlim(left = 0, right = len(y_test)) 
plt.ylim(bottom = 0.3) 

# set grid
plt.grid(color='gray', linestyle='--', linewidth=1)

plt.xticks(np.arange(0,1500,300))
plt.yticks(np.arange(0,2000,400))

# save & display figure
plt.show()

# %%
#모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: ', trainScore)
#valScore = model.evaluate(x_val, y_val, verbose=0)
#print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: ', testScore)
# Out:
# Train Score:  46000.937812219985
# Test Score:  50809.926490453894

# %%
#MAPE

y_test, y_pred = np.array(y_test), np.array(y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE: ', mape)
# Out:
# MAPE:  15.948009783932223
